# %% [markdown]
# <a href="https://colab.research.google.com/github/frandalmolin/Desenvolvimento_9/blob/main/Desafios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(6):
  if (i < 3):
    continue
  print("Rega a planta " + str(i))
# Out:
# Rega a planta 3
# Rega a planta 4
# Rega a planta 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(0,6):
  if i < 2:
    continue
  if i > 3:
    continue
  print("Rega a planta " + str(i))
# Out:
# Rega a planta 2
# Rega a planta 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(5, -1, -1):
  print ("Rega a planta " + str(i))
# Out:
# Rega a planta 5
# Rega a planta 4
# Rega a planta 3
# Rega a planta 2
# Rega a planta 1
# Rega a planta 0
